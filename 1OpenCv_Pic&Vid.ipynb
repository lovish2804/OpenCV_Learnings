# %%
import cv2

# %% [markdown]
# ## Importing and saving Photos

# %%
img=cv2.imread('img.jpg',-1)

# %%
cv2.imshow('image',img)
k=cv2.waitKey(0)
if k==27:
    cv2.destroyAllWindows()
elif k==ord('s'):
        cv2.imwrite('img_copyy.png',img)
        cv2.destroyAllWindows()

# %% [markdown]
# ## Using Camera

# %%
cap=cv2.VideoCapture(0);
## Saving the video
fourcc=cv2.VideoWriter_fourcc(*'XVID')
out=cv2.VideoWriter('output.avi',fourcc,20.0,(640,480))

while(cap.isOpened()):
    ret,frame=cap.read()
    
    # print(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    # print(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    #Every property has anumber assiciated with it and we can chng by cap.set(3,1080)
    print(cap.get(3))
    print(cap.get(4))
    if ret==True:
    # FOR DIPLAYING IMAGE IN GRAY COLOR
    #gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    #cv2.imshow('frame',gray)
        out.write(frame)
        cv2.imshow('frame',frame)
        if cv2.waitKey(1)==ord('q'):
             break
    else:
        break
   
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# ...

# %% [markdown]
# ## For video capturing properties refer to video
# https://docs.opencv.org/4.0.0/d4/d15/group__videoio__flags__base.html#gaeb8dd9c89c10a5c63c139bf7c4f5704d
